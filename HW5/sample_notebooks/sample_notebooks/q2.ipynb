# %%
import skfuzzy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
x, y = make_blobs(100, 2, centers=3)

(x, y)
# Out:
# (array([[ -5.86141785,   7.24210909],
#         [ -7.31815855,  -7.66994284],
#         [  6.77017438,  -3.76209666],
#         [  5.98218123,  -5.17311119],
#         [ -6.12019155,   9.41958339],
#         [ -7.27374825,  -8.77024778],
#         [ -9.31090657,  -9.31513135],
#         [  6.18972615,  -1.55503341],
#         [ -8.52381407,  -7.99776165],
#         [ -6.99721455,   8.75747775],
#         [ -6.94090633,  -9.37094974],
#         [  6.42656897,  -3.85807506],
#         [ -6.90812697,  -7.50112862],
#         [ -7.34913075,  -9.5164494 ],
#         [  6.68369818,  -4.22832323],
#         [ -5.22815115,   7.50291902],
#         [ -6.58513961,   7.12809758],
#         [ -5.44153353,   8.51777464],
#         [ -6.42850967,   8.99387451],
#         [ -5.89638025,   6.81576995],
#         [ -4.05824784,   8.70137145],
#         [ -8.41803517,  -9.93972368],
#         [ -6.99082708,   8.54146335],
#         [  7.40119161,  -2.40471927],
#         [  5.93431451,  -2.96531115],
#         [ -5.70602634,   8.94305785],
#         [ -5.78718623,   9.95455696],
#         [  6.10055415,  -4.41397165],
#         [  5.9716021 ,  -1.74346259],
#         [  6.13131759,  -2.87516962],
#         [  6.54843107,  -0.90166434],
#         [ -7.7995886 ,  -7.24015154],
#         [ -8.24273557, -10.2014371 ],
#         [ -6.82713064,  -8.44505123],
#         [  6.33307529,  -4.75284967],
#         [ -5.66363869,   7.29833871],
#         [  8.01722461,  -2.1455812 ],
#         [ -5.94384795,   8.67963773],
#         [  7.16576991,  -3.80265334],
#         [ -7.72838831,  -9.78786229],
#         [ -5.99209314,  10.22857044],
#         [  7.12790116,  -3.83732881],
#         [ -6.68236914,  -7.98643062],
#         [  6.02432024,  -2.9589474 ],
#         [ -6.95938851,   7.04248988],
#         [ -8.91396959,  -7.61826399],
#         [  6.42367118,  -4.3019656 ],
#         [ -7.51917705,   9.87719599],
#         [ -7.82620209,   7.37036107],
#         [  7.53187457,  -2.99694322],
#         [ -5.51825817,   7.24000883],
#         [ -5.6229869 ,   7.38744541],
#         [  6.69458625,  -2.72280823],
#         [ -8.4999388 ,  -8.48549519],
#         [ -4.61064342,   7.13586313],
#         [ -5.28225219,   8.92199313],
#         [  5.63402927,  -2.99480675],
#         [ -8.04938797,  -8.7280451 ],
#         [ -6.69555207,  -9.51531916],
#         [  5.3893989 ,  -4.50907865],
#         [  6.2965061 ,  -3.37619456],
#         [  5.5962306 ,  -1.63465883],
#         [ -6.15112119,   6.38794226],
#         [  8.04994472,  -2.7437695 ],
#         [ -8.62592013,  -9.17718598],
#         [ -5.80823241,   6.01570793],
#         [ -9.4701222 ,  -7.27352589],
#         [ -6.43098842,   9.27546893],
#         [ -8.34381893,  -8.50683534],
#         [ -7.73192451, -10.75554096],
#         [ -7.18727769,   7.42907506],
#         [ -8.97843609,  -6.85043385],
#         [  6.29155674,  -4.75339304],
#         [ -8.03377319,  -8.49746629],
#         [  6.50275526,  -2.50305595],
#         [ -7.67936111,   8.81252521],
#         [ -5.24298386,   7.33735887],
#         [ -8.41161925,  -8.32649441],
#         [  6.85280483,  -4.09240496],
#         [ -7.99900749,  -7.07169384],
#         [  7.06395988,  -3.26549329],
#         [ -9.9052312 ,  -5.9758429 ],
#         [  6.21287395,  -3.29189013],
#         [ -7.36743115,  -8.77503543],
#         [ -7.5300587 ,  -8.35020292],
#         [  5.99969952,  -2.61328179],
#         [ -6.48919412,  -8.42493841],
#         [ -5.46652942,   7.04867845],
#         [ -4.79349695,   9.61513349],
#         [ -7.4976192 ,  -7.71943856],
#         [ -8.07389435,  -7.11362835],
#         [  5.98656488,  -3.88971861],
#         [  7.23804399,  -3.99385756],
#         [ -7.18447983,   8.85238504],
#         [  6.43662267,  -2.15462675],
#         [ -4.25637571,   6.66142064],
#         [ -7.95692757,  -8.46653825],
#         [ -9.14394307,  -8.99648961],
#         [ -5.46554027,   8.84377564],
#         [  7.04586139,  -3.50803615]]),
#  array([1, 2, 0, 0, 1, 2, 2, 0, 2, 1, 2, 0, 2, 2, 0, 1, 1, 1, 1, 1, 1, 2,
#         1, 0, 0, 1, 1, 0, 0, 0, 0, 2, 2, 2, 0, 1, 0, 1, 0, 2, 1, 0, 2, 0,
#         1, 2, 0, 1, 1, 0, 1, 1, 0, 2, 1, 1, 0, 2, 2, 0, 0, 0, 1, 0, 2, 1,
#         2, 1, 2, 2, 1, 2, 0, 2, 0, 1, 1, 2, 0, 2, 0, 2, 0, 2, 2, 0, 2, 1,
#         1, 2, 2, 0, 0, 1, 0, 1, 2, 2, 1, 0]))

# %%
plt.scatter(x[:, 0], x[:, 1], c=y)

# %%
# Normalizing the data

# %%
num_clusters = 3

cntr, u, u0, d, jm, p, fpc = skfuzzy.cluster.cmeans(x.T, num_clusters, 2, error=0.005, maxiter=1000, init=None)

cluster_membership = np.argmax(u, axis=0)


fig, ax = plt.subplots()

for i in range(num_clusters):
    ax.plot(x[cluster_membership == i, 0], x[cluster_membership == i, 1], 'o', label=f'Cluster {i + 1}')

for cluster_center in cntr:
    ax.plot(cluster_center[0], cluster_center[1], 'X', markersize=10, markeredgewidth=2, label='Cluster Center')

ax.set_title('Fuzzy C-Means Clustering')
ax.legend()
plt.show()

print(f'FPC = {fpc}')
# Out:
# FPC = 0.9745525785603308
